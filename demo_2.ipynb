# %% [markdown]
# # 老照片说话demo

# %% [markdown]
# ### 获取已修复图片

# %%
image_path = '/home/advance/dev/insightface/files/images/夫妻.jpeg'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def show_image(image_path):
    # 读取图片
    img = mpimg.imread(image_path)
    
    # 展示图片
    plt.imshow(img)
    plt.axis('off')  # 关闭坐标轴
    plt.show()
show_image(image_path)

# %% [markdown]
# ### 根据人物对图片进行左右分割

# %%
from did_t2v import *
from show_image import show_two_images
bboxes, img = get_face_bboxes(image_path)
image2video_list = list_single_image_faces_info(img, bboxes)

left_image = image2video_list[0][0]
right_image = image2video_list[1][0]
show_two_images(left_image, right_image)
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.10 (you have 1.4.8). Upgrade using: pip install --upgrade albumentations
# /home/advance/miniconda3/envs/insightface/lib/python3.8/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:69: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/advance/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/advance/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/advance/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/advance/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# WARNING:py.warnings:/home/advance/miniconda3/envs/insightface/lib/python3.8/site-packages/insightface/utils/transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/advance/.insightface/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %% [markdown]
# ### 创建文本信息A+A角色图像

# %%
A_image = left_image
A_text_list = ["看，你穿婚纱的样子真美，我好像又看到了我们第一次相遇的那一刻","亲爱的，这一刻我想永远记住。你的笑容，你的眼睛，还有我们之间的这份爱"]

# %% [markdown]
# ### 创建文本信息B+B角色图像

# %%
B_image = right_image
B_text_list = ["是吗？那时候的我还很青涩呢。不过，能和你一起拍婚纱照，我觉得很幸福","我也是，亲爱的。这一刻我觉得我们是最幸福的"]

# %% [markdown]
# ### 循环请求，并等待生成结果

# %%
did_t2v = DIDT2V()

# %% [markdown]
# ### 得到a列表

# %%
a = []
for A_text in A_text_list:
    video_path = did_t2v.run(A_image, A_text)
    a.append(video_path)
# Out:
# upload file success
# ============== 看，你穿婚纱的样子真美，我好像又看到了我们第一次相遇的那一刻
# {"id":"tlk_IxiY6TJ9ObCa23AzqmK36","created_at":"2024-07-04T07:52:00.030Z","created_by":"auth0|6434b92cfb407e0d68664b2b","status":"created","object":"talk"}
# task_id=======>:tlk_IxiY6TJ9ObCa23AzqmK36
# {'user': {'features': ['stitch', 'no-watermark', 'clips:write', 'api-keys:write', 'subtitles', 'logo', 'translation', 'talks', 'logo', 'skip-moderation', 'skip-celebrity-detection'], 'stripe_customer_id': 'cus_NgtwQejpVq7fHK', 'stripe_plan_group': 'deid-enterprise', 'authorizer': 'basic', 'org_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'owner_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'id': 'auth0|6434b92cfb407e0d68664b2b', 'plan': 'deid-enterprise', 'email': 'luoxin@jshine.cc'}, 'script': {'length': 30, 'subtitles': False, 'type': 'text', 'provider': {'type': 'microsoft', 'voice_id': 'zh-CN-XiaoyiNeural'}}, 'audio_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_IxiY6TJ9ObCa23AzqmK36/microsoft.wav?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1720165920&Signature=dNWxTDRDuu%2FIHHzltom1i3eNxKs%3D', 'created_at': '2024-07-04T07:52:00.030Z', 'config': {'stitch': True, 'align_driver': True, 'sharpen': True, 'normalization_factor': 1, 'result_format': '.mp4', 'fluent': True, 'pad_audio': 2, 'reduce_noise': False, 'auto_match': True, 'show_watermark': False, 'logo': {'url': 'ai', 'position': [0, 0]}, 'motion_factor': 1, 'align_expand_factor': 0.3}, 'source_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_IxiY6TJ9ObCa23AzqmK36/source/44548f646a714085b25e7fd88ee40eb9.png?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1720165920&Signature=chmeqMiCuCij%2BKb%2FdeK06RhEnh4%3D', 'created_by': 'auth0|6434b92cfb407e0d68664b2b', 'status': 'started', 'driver_url': 'bank://natural/', 'modified_at': '2024-07-04T07:52:00.211Z', 'user_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'subtitles': False, 'id': 'tlk_IxiY6TJ9ObCa23AzqmK36', 'duration': 9, 'started_at': '2024-07-04T07:52:00.074', 'pending_url': 's3://d-id-talks-prod/org_3F65YkhqT2ZOjNuEFRd38/tlk_IxiY6TJ9ObCa23AzqmK36/1720079520030.mp4'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 a = []
#       2 for A_text in A_text_list:
# ----> 3     video_path = did_t2v.run(A_image, A_text)
#       4     a.append(video_path)
#
# File ~/dev/insightface/did_t2v.py:103, in DIDT2V.run(self, image_file_path, text_input)
#     101 # 制作视频
#     102 task_id = self.send_task(image_url, text_input)
# --> 103 result_url = self.get_history(task_id=task_id)
#     105 # 获取视频并保存在本地
#     106 video = requests.get(result_url)
#
# File ~/dev/insightface/did_t2v.py:86, in DIDT2V.get_history(self, task_id)
#      84 for turn in range(10):
#      85     time.sleep(2)
# ---> 86     response = requests.get(url, headers=headers)
#      87     # print(response.text)
#      88     print(response.json())
#
# File ~/miniconda3/envs/insightface/lib/python3.8/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/insightface/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/insightface/lib/python3.8/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/insightface/lib/python3.8/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/insightface/lib/python3.8/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/insightface/lib/python3.8/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/miniconda3/envs/insightface/lib/python3.8/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniconda3/envs/insightface/lib/python3.8/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/envs/insightface/lib/python3.8/http/client.py:1322, in HTTPConnection.getresponse(self)
#    1320 try:
#    1321     try:
# -> 1322         response.begin()
#    1323     except ConnectionError:
#    1324         self.close()
#
# File ~/miniconda3/envs/insightface/lib/python3.8/http/client.py:303, in HTTPResponse.begin(self)
#     301 # read until we get a non-100 response
#     302 while True:
# --> 303     version, status, reason = self._read_status()
#     304     if status != CONTINUE:
#     305         break
#
# File ~/miniconda3/envs/insightface/lib/python3.8/http/client.py:264, in HTTPResponse._read_status(self)
#     263 def _read_status(self):
# --> 264     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265     if len(line) > _MAXLINE:
#     266         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/insightface/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/miniconda3/envs/insightface/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/insightface/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 得到B列表

# %%
b = []
for B_text in B_text_list:
    video_path = did_t2v.run(B_image, B_text)
    b.append(video_path)
# Out:
# upload file success
# ============== 是吗？那时候的我还很青涩呢。不过，能和你一起拍婚纱照，我觉得很幸福
# {"id":"tlk_dUrs-v_Vx47F4Ql3DJwVv","created_at":"2024-07-01T07:50:54.945Z","created_by":"auth0|6434b92cfb407e0d68664b2b","status":"created","object":"talk"}
# task_id=======>:tlk_dUrs-v_Vx47F4Ql3DJwVv
# {'user': {'features': ['stitch', 'no-watermark', 'clips:write', 'api-keys:write', 'subtitles', 'logo', 'translation', 'talks', 'logo', 'skip-moderation', 'skip-celebrity-detection'], 'stripe_customer_id': 'cus_NgtwQejpVq7fHK', 'stripe_plan_group': 'deid-enterprise', 'authorizer': 'basic', 'org_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'owner_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'id': 'auth0|6434b92cfb407e0d68664b2b', 'plan': 'deid-enterprise', 'email': 'luoxin@jshine.cc'}, 'script': {'length': 33, 'subtitles': False, 'type': 'text', 'provider': {'type': 'microsoft', 'voice_id': 'zh-CN-XiaoyiNeural'}}, 'audio_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_dUrs-v_Vx47F4Ql3DJwVv/microsoft.wav?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906654&Signature=ChBE%2FetXlbUKAal%2Fvw%2FTkF6QxKs%3D', 'created_at': '2024-07-01T07:50:54.945Z', 'config': {'stitch': True, 'align_driver': True, 'sharpen': True, 'normalization_factor': 1, 'result_format': '.mp4', 'fluent': True, 'pad_audio': 2, 'reduce_noise': False, 'auto_match': True, 'show_watermark': False, 'logo': {'url': 'ai', 'position': [0, 0]}, 'motion_factor': 1, 'align_expand_factor': 0.3}, 'source_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_dUrs-v_Vx47F4Ql3DJwVv/source/a998357bdab44b5ba290789601733e63.png?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906654&Signature=MXTtR6jCuJBC2s0lfllqQJYa8s8%3D', 'created_by': 'auth0|6434b92cfb407e0d68664b2b', 'status': 'started', 'driver_url': 'bank://natural/', 'modified_at': '2024-07-01T07:50:55.205Z', 'user_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'subtitles': False, 'id': 'tlk_dUrs-v_Vx47F4Ql3DJwVv', 'duration': 10, 'started_at': '2024-07-01T07:50:54.997', 'pending_url': 's3://d-id-talks-prod/org_3F65YkhqT2ZOjNuEFRd38/tlk_dUrs-v_Vx47F4Ql3DJwVv/1719820254945.mp4'}
# {'user': {'features': ['stitch', 'no-watermark', 'clips:write', 'api-keys:write', 'subtitles', 'logo', 'translation', 'talks', 'logo', 'skip-moderation', 'skip-celebrity-detection'], 'stripe_customer_id': 'cus_NgtwQejpVq7fHK', 'stripe_plan_group': 'deid-enterprise', 'authorizer': 'basic', 'org_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'owner_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'id': 'auth0|6434b92cfb407e0d68664b2b', 'plan': 'deid-enterprise', 'email': 'luoxin@jshine.cc'}, 'script': {'length': 33, 'subtitles': False, 'type': 'text', 'provider': {'type': 'microsoft', 'voice_id': 'zh-CN-XiaoyiNeural'}}, 'audio_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_dUrs-v_Vx47F4Ql3DJwVv/microsoft.wav?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906654&Signature=ChBE%2FetXlbUKAal%2Fvw%2FTkF6QxKs%3D', 'created_at': '2024-07-01T07:50:54.945Z', 'config': {'stitch': True, 'align_driver': True, 'sharpen': True, 'normalization_factor': 1, 'result_format': '.mp4', 'fluent': True, 'pad_audio': 2, 'reduce_noise': False, 'auto_match': True, 'show_watermark': False, 'logo': {'url': 'ai', 'position': [0, 0]}, 'motion_factor': 1, 'align_expand_factor': 0.3}, 'source_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_dUrs-v_Vx47F4Ql3DJwVv/source/a998357bdab44b5ba290789601733e63.png?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906654&Signature=MXTtR6jCuJBC2s0lfllqQJYa8s8%3D', 'created_by': 'auth0|6434b92cfb407e0d68664b2b', 'status': 'started', 'driver_url': 'bank://natural/', 'modified_at': '2024-07-01T07:50:55.205Z', 'user_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'subtitles': False, 'id': 'tlk_dUrs-v_Vx47F4Ql3DJwVv', 'duration': 10, 'started_at': '2024-07-01T07:50:54.997', 'pending_url': 's3://d-id-talks-prod/org_3F65YkhqT2ZOjNuEFRd38/tlk_dUrs-v_Vx47F4Ql3DJwVv/1719820254945.mp4'}
# {'user': {'features': ['stitch', 'no-watermark', 'clips:write', 'api-keys:write', 'subtitles', 'logo', 'translation', 'talks', 'logo', 'skip-moderation', 'skip-celebrity-detection'], 'stripe_customer_id': 'cus_NgtwQejpVq7fHK', 'stripe_plan_group': 'deid-enterprise', 'authorizer': 'basic', 'org_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'owner_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'id': 'auth0|6434b92cfb407e0d68664b2b', 'plan': 'deid-enterprise', 'email': 'luoxin@jshine.cc'}, 'script': {'length': 33, 'subtitles': False, 'type': 'text', 'provider': {'type': 'microsoft', 'voice_id': 'zh-CN-XiaoyiNeural'}}, 'metadata': {'driver_url': 'bank://natural/driver-3/flipped', 'mouth_open': False, 'num_faces': 1, 'num_frames': 190, 'processing_fps': 35.590028348394156, 'resolution': [456, 1280], 'size_kib': 1072.03515625}, 'audio_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_dUrs-v_Vx47F4Ql3DJwVv/microsoft.wav?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906654&Signature=ChBE%2FetXlbUKAal%2Fvw%2FTkF6QxKs%3D', 'created_at': '2024-07-01T07:50:54.945Z', 'face': {'mask_confidence': 1, 'detection': [38, 396, 279, 704], 'overlap': 'no', 'size': 500, 'top_left': [-63, 255], 'face_id': 0, 'detect_confidence': 0.99964439868927}, 'config': {'stitch': True, 'align_driver': True, 'sharpen': True, 'normalization_factor': 1, 'result_format': '.mp4', 'fluent': True, 'pad_audio': 2, 'reduce_noise': False, 'auto_match': True, 'show_watermark': False, 'logo': {'url': 'ai', 'position': [0, 0]}, 'motion_factor': 1, 'align_expand_factor': 0.3}, 'source_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_dUrs-v_Vx47F4Ql3DJwVv/source/a998357bdab44b5ba290789601733e63.png?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906654&Signature=MXTtR6jCuJBC2s0lfllqQJYa8s8%3D', 'created_by': 'auth0|6434b92cfb407e0d68664b2b', 'status': 'done', 'driver_url': 'bank://natural/', 'modified_at': '2024-07-01T07:51:00.381Z', 'user_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'subtitles': False, 'id': 'tlk_dUrs-v_Vx47F4Ql3DJwVv', 'duration': 10, 'started_at': '2024-07-01T07:50:54.997', 'result_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_dUrs-v_Vx47F4Ql3DJwVv/1719820254945.mp4?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906660&Signature=lwBsPRk4NRCCpwdslYvqdA5nZMM%3D'}
# upload file success
# ============== 我也是，亲爱的。这一刻我觉得我们是最幸福的
# {"id":"tlk_iWFu47gUGBUWQi1iYeQ0l","created_at":"2024-07-01T07:51:19.085Z","created_by":"auth0|6434b92cfb407e0d68664b2b","status":"created","object":"talk"}
# task_id=======>:tlk_iWFu47gUGBUWQi1iYeQ0l
# {'user': {'features': ['stitch', 'no-watermark', 'clips:write', 'api-keys:write', 'subtitles', 'logo', 'translation', 'talks', 'logo', 'skip-moderation', 'skip-celebrity-detection'], 'stripe_customer_id': 'cus_NgtwQejpVq7fHK', 'stripe_plan_group': 'deid-enterprise', 'authorizer': 'basic', 'org_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'owner_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'id': 'auth0|6434b92cfb407e0d68664b2b', 'plan': 'deid-enterprise', 'email': 'luoxin@jshine.cc'}, 'script': {'length': 21, 'subtitles': False, 'type': 'text', 'provider': {'type': 'microsoft', 'voice_id': 'zh-CN-XiaoyiNeural'}}, 'audio_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_iWFu47gUGBUWQi1iYeQ0l/microsoft.wav?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906679&Signature=n%2FJXryxdRXGNAb7bxzI3cSUKLnk%3D', 'created_at': '2024-07-01T07:51:19.085Z', 'config': {'stitch': True, 'align_driver': True, 'sharpen': True, 'normalization_factor': 1, 'result_format': '.mp4', 'fluent': True, 'pad_audio': 2, 'reduce_noise': False, 'auto_match': True, 'show_watermark': False, 'logo': {'url': 'ai', 'position': [0, 0]}, 'motion_factor': 1, 'align_expand_factor': 0.3}, 'source_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_iWFu47gUGBUWQi1iYeQ0l/source/7b9926563486438590781dcd08434fb1.png?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906679&Signature=CoJga4lju5vPOfIvyoi5TmTWhTI%3D', 'created_by': 'auth0|6434b92cfb407e0d68664b2b', 'status': 'started', 'driver_url': 'bank://natural/', 'modified_at': '2024-07-01T07:51:19.283Z', 'user_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'subtitles': False, 'id': 'tlk_iWFu47gUGBUWQi1iYeQ0l', 'duration': 8, 'started_at': '2024-07-01T07:51:19.151', 'pending_url': 's3://d-id-talks-prod/org_3F65YkhqT2ZOjNuEFRd38/tlk_iWFu47gUGBUWQi1iYeQ0l/1719820279085.mp4'}
# {'user': {'features': ['stitch', 'no-watermark', 'clips:write', 'api-keys:write', 'subtitles', 'logo', 'translation', 'talks', 'logo', 'skip-moderation', 'skip-celebrity-detection'], 'stripe_customer_id': 'cus_NgtwQejpVq7fHK', 'stripe_plan_group': 'deid-enterprise', 'authorizer': 'basic', 'org_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'owner_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'id': 'auth0|6434b92cfb407e0d68664b2b', 'plan': 'deid-enterprise', 'email': 'luoxin@jshine.cc'}, 'script': {'length': 21, 'subtitles': False, 'type': 'text', 'provider': {'type': 'microsoft', 'voice_id': 'zh-CN-XiaoyiNeural'}}, 'metadata': {'driver_url': 'bank://natural/driver-3/flipped', 'mouth_open': False, 'num_faces': 1, 'num_frames': 129, 'processing_fps': 29.844551530088516, 'resolution': [456, 1280], 'size_kib': 753.6259765625}, 'audio_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_iWFu47gUGBUWQi1iYeQ0l/microsoft.wav?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906679&Signature=n%2FJXryxdRXGNAb7bxzI3cSUKLnk%3D', 'created_at': '2024-07-01T07:51:19.085Z', 'face': {'mask_confidence': 1, 'detection': [38, 396, 279, 704], 'overlap': 'no', 'size': 500, 'top_left': [-63, 255], 'face_id': 0, 'detect_confidence': 0.99964439868927}, 'config': {'stitch': True, 'align_driver': True, 'sharpen': True, 'normalization_factor': 1, 'result_format': '.mp4', 'fluent': True, 'pad_audio': 2, 'reduce_noise': False, 'auto_match': True, 'show_watermark': False, 'logo': {'url': 'ai', 'position': [0, 0]}, 'motion_factor': 1, 'align_expand_factor': 0.3}, 'source_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_iWFu47gUGBUWQi1iYeQ0l/source/7b9926563486438590781dcd08434fb1.png?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906679&Signature=CoJga4lju5vPOfIvyoi5TmTWhTI%3D', 'created_by': 'auth0|6434b92cfb407e0d68664b2b', 'status': 'done', 'driver_url': 'bank://natural/', 'modified_at': '2024-07-01T07:51:23.577Z', 'user_id': 'org_3F65YkhqT2ZOjNuEFRd38', 'subtitles': False, 'id': 'tlk_iWFu47gUGBUWQi1iYeQ0l', 'duration': 8, 'started_at': '2024-07-01T07:51:19.151', 'result_url': 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/org_3F65YkhqT2ZOjNuEFRd38/tlk_iWFu47gUGBUWQi1iYeQ0l/1719820279085.mp4?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1719906683&Signature=mrhLk1OSyF6Yst89yU4l90iu%2FGU%3D'}

# %% [markdown]
# ### 展示D-ID生成结果

# %%
from IPython.display import Video
Video(video_path)
# Out:
# <video src="./temp/7ea04261-ab16-4355-97f9-a642555dc964.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### 将列表中的元素与原图进行拼接，得到aA、bB列表

# %%
import mov_on_image

# %%
video_size_left = image2video_list[0][1]
desired_video_coord_on_image_left = image2video_list[0][2]
video_size_right = image2video_list[1][1]
desired_video_coord_on_image_right = image2video_list[1][2]

# %%
aA = []
for a_ in a:
    output_file_path = mov_on_image.process_v2(image_path, a_, video_size_left, desired_video_coord_on_image_left)
    print(output_file_path)
    aA.append(output_file_path)
# Out:
# Moviepy - Building video ./temp/composite_videoa0ec93f9-d6d8-40f9-9a41-80c0358b138c.mp4.
# MoviePy - Writing audio in composite_videoa0ec93f9-d6d8-40f9-9a41-80c0358b138cTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./temp/composite_videoa0ec93f9-d6d8-40f9-9a41-80c0358b138c.mp4
# t:  97%|█████████▋| 152/157 [00:02<00:00, 62.33it/s, now=None]WARNING:py.warnings:/home/advance/miniconda3/envs/insightface/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./temp/7c062a66-a47b-46cc-9f61-4f00533ad805.mp4, 1528320 bytes wanted but 0 bytes read,at frame 156/157, at time 6.24/6.26 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready ./temp/composite_videoa0ec93f9-d6d8-40f9-9a41-80c0358b138c.mp4
# ./temp/composite_videoa0ec93f9-d6d8-40f9-9a41-80c0358b138c.mp4
# Moviepy - Building video ./temp/composite_video7b2576c2-377d-4211-b0cb-ed2b3a685d1c.mp4.
# MoviePy - Writing audio in composite_video7b2576c2-377d-4211-b0cb-ed2b3a685d1cTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./temp/composite_video7b2576c2-377d-4211-b0cb-ed2b3a685d1c.mp4
# t:  99%|█████████▉| 174/175 [00:02<00:00, 64.07it/s, now=None]WARNING:py.warnings:/home/advance/miniconda3/envs/insightface/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./temp/039820d4-eb3f-498f-8030-6a9d21e53b62.mp4, 1528320 bytes wanted but 0 bytes read,at frame 174/175, at time 6.96/6.98 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready ./temp/composite_video7b2576c2-377d-4211-b0cb-ed2b3a685d1c.mp4
# ./temp/composite_video7b2576c2-377d-4211-b0cb-ed2b3a685d1c.mp4

# %%
bB = []
for b_ in b:
    output_file_path = mov_on_image.process_v2(image_path, b_, video_size_right, desired_video_coord_on_image_right)
    bB.append(output_file_path)
# Out:
# Moviepy - Building video ./temp/composite_video8b32e6da-57aa-4e93-975c-f2ef2d21faf9.mp4.
# MoviePy - Writing audio in composite_video8b32e6da-57aa-4e93-975c-f2ef2d21faf9TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./temp/composite_video8b32e6da-57aa-4e93-975c-f2ef2d21faf9.mp4
# t:  99%|█████████▉| 190/191 [00:02<00:00, 64.37it/s, now=None]WARNING:py.warnings:/home/advance/miniconda3/envs/insightface/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./temp/8a0a255a-bffd-4e77-8336-a972d05d1098.mp4, 1751040 bytes wanted but 0 bytes read,at frame 190/191, at time 7.60/7.63 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready ./temp/composite_video8b32e6da-57aa-4e93-975c-f2ef2d21faf9.mp4
# Moviepy - Building video ./temp/composite_videod41a3621-a980-48cc-bf4c-384a8424acaa.mp4.
# MoviePy - Writing audio in composite_videod41a3621-a980-48cc-bf4c-384a8424acaaTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./temp/composite_videod41a3621-a980-48cc-bf4c-384a8424acaa.mp4
# t:  95%|█████████▌| 124/130 [00:01<00:00, 59.47it/s, now=None]WARNING:py.warnings:/home/advance/miniconda3/envs/insightface/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./temp/7ea04261-ab16-4355-97f9-a642555dc964.mp4, 1751040 bytes wanted but 0 bytes read,at frame 129/130, at time 5.16/5.18 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready ./temp/composite_videod41a3621-a980-48cc-bf4c-384a8424acaa.mp4

# %% [markdown]
# ### 展示一个合成的视频

# %%
Video(bB[0])
# Out:
# <video src="./temp/composite_video8b32e6da-57aa-4e93-975c-f2ef2d21faf9.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### aA列表中的视频与bB列表中的视频进行交叉合成

# %%
def generator(list:list):
    for element in list:
        yield element

# %%
aA_bB = []
gen_obj = generator(bB)
for aA_ in aA:
    aA_bB.append(aA_)
    aA_bB.append(next(gen_obj))

# %%
output_file_path = "concatenate_video.mp4"
mov_on_image.concatenate_videos(aA_bB, output_file_path)
# Out:
# Moviepy - Building video concatenate_video.mp4.
# MoviePy - Writing audio in concatenate_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video concatenate_video.mp4
# t:  21%|██▏       | 140/656 [00:00<00:02, 203.49it/s, now=None]WARNING:py.warnings:/home/advance/miniconda3/envs/insightface/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./temp/composite_videoa0ec93f9-d6d8-40f9-9a41-80c0358b138c.mp4, 5382480 bytes wanted but 0 bytes read,at frame 157/158, at time 6.28/6.30 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  50%|█████     | 331/656 [00:01<00:01, 197.20it/s, now=None]WARNING:py.warnings:/home/advance/miniconda3/envs/insightface/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./temp/composite_video8b32e6da-57aa-4e93-975c-f2ef2d21faf9.mp4, 5382480 bytes wanted but 0 bytes read,at frame 191/193, at time 7.64/7.68 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  80%|███████▉  | 522/656 [00:02<00:00, 199.73it/s, now=None]WARNING:py.warnings:/home/advance/miniconda3/envs/insightface/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./temp/composite_video7b2576c2-377d-4211-b0cb-ed2b3a685d1c.mp4, 5382480 bytes wanted but 0 bytes read,at frame 175/176, at time 7.00/7.03 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready concatenate_video.mp4
# 'concatenate_video.mp4'

# %%
len(aA_bB)
# Out:
# 4

# %% [markdown]
# ### 展示结果

# %%
Video(output_file_path)
# Out:
# <video src="concatenate_video.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
